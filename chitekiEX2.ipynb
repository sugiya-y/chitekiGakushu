# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
# Define Density function
def ndist( x, mu=0., sigma=1. ):
    coef = 1./np.sqrt( 2. * np.pi * sigma**2 )
    dnst = np.exp( -.5 * ((x-mu)/sigma)**2 )
    return coef * dnst

# %% [markdown]
# # ex(1)

# %%
tmu = 1
tsigma = 1
N = 10
# Ideal Density curve
xrng = np.linspace( tmu-4*tsigma, tmu+4*tsigma, 100 )
truecurve = ndist( xrng, tmu, tsigma )
# Generate Sample data as xsamp
xsamp = tmu + tsigma * np.random.randn( N )
# Inference of parameters
mu = np.mean( xsamp )
sigma = np.sqrt( np.mean(xsamp**2) - mu**2 )
estcurve = ndist( xrng, mu, sigma )
plt.hist( xsamp, normed=True, alpha=0.5 )
plt.plot( xrng, truecurve, 'g-', linewidth=2 )
plt.plot( xrng, estcurve, 'r-', linewidth=2 )
plt.grid(linestyle=':')
plt.show()

# %%
tmu = 1
tsigma = 1
N = 100
# Ideal Density curve
xrng = np.linspace( tmu-4*tsigma, tmu+4*tsigma, 100 )
truecurve = ndist( xrng, tmu, tsigma )
# Generate Sample data as xsamp
xsamp = tmu + tsigma * np.random.randn( N )
# Inference of parameters
mu = np.mean( xsamp )
sigma = np.sqrt( np.mean(xsamp**2) - mu**2 )
estcurve = ndist( xrng, mu, sigma )
plt.hist( xsamp, normed=True, alpha=0.5 )
plt.plot( xrng, truecurve, 'g-', linewidth=2 )
plt.plot( xrng, estcurve, 'r-', linewidth=2 )
plt.grid(linestyle=':')
plt.show()

# %%
tmu = 1
tsigma = 1
N = 1000
# Ideal Density curve
xrng = np.linspace( tmu-4*tsigma, tmu+4*tsigma, 100 )
truecurve = ndist( xrng, tmu, tsigma )
# Generate Sample data as xsamp
xsamp = tmu + tsigma * np.random.randn( N )
# Inference of parameters
mu = np.mean( xsamp )
sigma = np.sqrt( np.mean(xsamp**2) - mu**2 )
estcurve = ndist( xrng, mu, sigma )
plt.hist( xsamp, normed=True, alpha=0.5 )
plt.plot( xrng, truecurve, 'g-', linewidth=2 )
plt.plot( xrng, estcurve, 'r-', linewidth=2 )
plt.grid(linestyle=':')
plt.show()

# %% [markdown]
# # ex(2)

# %%
tmus = []
tsigmas = []
mus = []
sigmas = []

tmu = 1
tsigma = 1
# Ideal Density curve
xrng = range(1000)
for i in range(1000):
    N = i
    # Generate Sample data as xsamp
    xsamp = tmu + tsigma * np.random.randn( N )
    # Inference of parameters
    mu = np.mean( xsamp )
    sigma = np.sqrt( np.mean(xsamp**2) - mu**2 )
    tmus.append(tmu)
    tsigmas.append(tsigma)
    mus.append(mu)
    sigmas.append(sigma)
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.plot( xrng, mus, 'b-', linewidth=2 )
plt.plot( xrng, tmus, 'r-', linewidth=2 )
plt.grid(linestyle=':')
plt.title("mu")
plt.show()

# %%
plt.plot( xrng, sigmas, 'b-', linewidth=2 )
plt.plot( xrng, tsigmas, 'r-', linewidth=2 )
plt.grid(linestyle=':')
plt.title("sigma")
plt.show()
